# %% [markdown]
# # NovaCode Cloud — Autonomous Remote AI Coding Environment
#
# This notebook bootstraps and executes the NovaCode Cloud backend engine on Kaggle Free GPU compute.
#
# - **Backend Engine:** vLLM OpenAI-Compatible Server + Qwen2.5-Coder
# - **Agent Interface:** OpenCode Agent
# - **Source of Truth:** GitHub (Session-resilient)

# %%
# Step 1: Detect Environment & Hardware
# !bash scripts/detect_environment.sh

# %%
# Step 2: Install Dependencies & vLLM Engine
# !bash scripts/install_dependencies.sh
# !bash scripts/install_vllm.sh
# !bash scripts/install_opencode.sh

# %%
# Step 3: Start vLLM Model Server in Background
# !bash scripts/start_vllm.sh

# %%
# Step 4: Run System Healthcheck
# !bash scripts/healthcheck.sh

# %%
# Step 5: Start OpenCode Agent Engine & Monitor Resources
# !bash scripts/start_opencode.sh
# !bash scripts/resource_monitor.sh
